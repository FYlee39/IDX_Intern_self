# %%
from func import *

# %%
train_df = pd.read_csv("train_df_clean.csv")
test_df = pd.read_csv("test_df_clean.csv")

# %%
data_quality_summary(train_df)
# Out:
#                                   column    dtype  n_unique  missing_%  \
# 22                       SubdivisionName   object      5592      65.23
# 23                        BuyerOfficeAOR   object        59       5.90
# 6                         ListAgentEmail   object     30616       0.35
# 25                   StreetNumberNumeric  float64     23252       0.08
# 11                       UnparsedAddress   object     65226       0.06
# 0                          BuyerAgentAOR   object        52       0.02
# 1                           ListAgentAOR   object        52       0.02
# 41                        log_ClosePrice  float64      7373       0.00
# 33                           LotSizeArea  float64     14538       0.00
# 34                     MainLevelBedrooms  float64        22       0.00
# 35                     NewConstructionYN     bool         2       0.00
# 36                          GarageSpaces  float64        27       0.00
# 37                    HighSchoolDistrict   object       388       0.00
# 38                            PostalCode   object      1637       0.00
# 39                        AssociationFee  float64      1249       0.00
# 40                     LotSizeSquareFeet  float64     14442       0.00
# 43        HighSchoolDistrict_target_mean  float64       387       0.00
# 42                            ZIP_prefix    int64        57       0.00
# 31                           FireplaceYN     bool         2       0.00
# 44                  Flooring_target_mean  float64       225       0.00
# 45                      Levels_final_One    int64         2       0.00
# 46              Levels_final_ThreeOrMore    int64         2       0.00
# 47                      Levels_final_Two    int64         2       0.00
# 48       AssociationFeeFrequency_Monthly    int64         2       0.00
# 49     AssociationFeeFrequency_Quarterly    int64         2       0.00
# 50  AssociationFeeFrequency_SemiAnnually    int64         2       0.00
# 51                           Stories_1.5    int64         2       0.00
# 52                           Stories_2.0    int64         2       0.00
# 53                        LivingArea_std  float64      4823       0.00
# 54                 LotSizeSquareFeet_std  float64     14442       0.00
# 32                                Levels   object        16       0.00
# 28                                  City   object       839       0.00
# 30                       StateOrProvince   object         1       0.00
# 29                         BedroomsTotal  float64        14       0.00
# 2                               Flooring   object       233       0.00
# 3                                 ViewYN     bool         2       0.00
# 4                          PoolPrivateYN     bool         2       0.00
# 5                             ListingKey    int64     65517       0.00
# 7                              CloseDate   object       182       0.00
# 8                             ClosePrice  float64      7373       0.00
# 9                               Latitude  float64     63638       0.00
# 10                             Longitude  float64     64064       0.00
# 12                          PropertyType   object         1       0.00
# 13                            LivingArea  float64      4823       0.00
# 14                     ListingKeyNumeric    int64     65517       0.00
# 15                          MLSAreaMajor   object       956       0.00
# 16                        CountyOrParish   object        54       0.00
# 17                             MlsStatus   object         1       0.00
# 18                      AttachedGarageYN     bool         2       0.00
# 19                          ParkingTotal  float64        47       0.00
# 20                       PropertySubType   object         1       0.00
# 21                          LotSizeAcres  float64      6519       0.00
# 24                             YearBuilt  float64       153       0.00
# 26                             ListingId   object     65517       0.00
# 27                 BathroomsTotalInteger  float64        16       0.00
# 55                    AssociationFee_std  float64      1249       0.00
#
#     num_missing
# 22        42738
# 23         3865
# 6           228
# 25           55
# 11           41
# 0            11
# 1            11
# 41            0
# 33            0
# 34            0
# 35            0
# 36            0
# 37            0
# 38            0
# 39            0
# 40            0
# 43            0
# 42            0
# 31            0
# 44            0
# 45            0
# 46            0
# 47            0
# 48            0
# 49            0
# 50            0
# 51            0
# 52            0
# 53            0
# 54            0
# 32            0
# 28            0
# 30            0
# 29            0
# 2             0
# 3             0
# 4             0
# 5             0
# 7             0
# 8             0
# 9             0
# 10            0
# 12            0
# 13            0
# 14            0
# 15            0
# 16            0
# 17            0
# 18            0
# 19            0
# 20            0
# 21            0
# 24            0
# 26            0
# 27            0
# 55            0

# %%
train_df = train_df.drop(["HighSchoolDistrict_target_mean", "Flooring_target_mean", "LivingArea_std", "LotSizeSquareFeet_std", "AssociationFee_std"], axis=1)

# %%
no_missing_train_df = train_df.dropna(axis=1)

# %%
data_quality_summary(test_df)
# Out:
#                                   column    dtype  n_unique  missing_%  \
# 22                       SubdivisionName   object      1708      66.25
# 23                        BuyerOfficeAOR   object        55       9.27
# 6                         ListAgentEmail   object      7744       0.26
# 25                   StreetNumberNumeric  float64      6917       0.16
# 11                       UnparsedAddress   object      9977       0.11
# 0                          BuyerAgentAOR   object        52       0.00
# 42                            ZIP_prefix    int64        57       0.00
# 33                           LotSizeArea  float64      4670       0.00
# 34                     MainLevelBedrooms  float64        14       0.00
# 35                     NewConstructionYN     bool         2       0.00
# 36                          GarageSpaces  float64        18       0.00
# 37                    HighSchoolDistrict   object       319       0.00
# 38                            PostalCode   object      1043       0.00
# 39                        AssociationFee  float64       597       0.00
# 40                     LotSizeSquareFeet  float64      4631       0.00
# 41                        log_ClosePrice  float64      2326       0.00
# 43        HighSchoolDistrict_target_mean  float64       314       0.00
# 31                           FireplaceYN     bool         2       0.00
# 44                  Flooring_target_mean  float64       125       0.00
# 45                      Levels_final_One    int64         2       0.00
# 46              Levels_final_ThreeOrMore    int64         2       0.00
# 47                      Levels_final_Two    int64         2       0.00
# 48       AssociationFeeFrequency_Monthly    int64         2       0.00
# 49     AssociationFeeFrequency_Quarterly    int64         2       0.00
# 50  AssociationFeeFrequency_SemiAnnually    int64         2       0.00
# 51                           Stories_1.5    int64         2       0.00
# 52                           Stories_2.0    int64         2       0.00
# 53                        LivingArea_std  float64      3020       0.00
# 54                 LotSizeSquareFeet_std  float64      4631       0.00
# 32                                Levels   object        13       0.00
# 28                                  City   object       625       0.00
# 30                       StateOrProvince   object         1       0.00
# 14                     ListingKeyNumeric    int64      9990       0.00
# 2                               Flooring   object       132       0.00
# 3                                 ViewYN     bool         2       0.00
# 4                          PoolPrivateYN     bool         2       0.00
# 5                             ListingKey    int64      9990       0.00
# 7                              CloseDate   object        30       0.00
# 8                             ClosePrice  float64      2326       0.00
# 9                               Latitude  float64      9895       0.00
# 10                             Longitude  float64      9905       0.00
# 12                          PropertyType   object         1       0.00
# 13                            LivingArea  float64      3020       0.00
# 15                          MLSAreaMajor   object       781       0.00
# 29                         BedroomsTotal  float64        13       0.00
# 16                        CountyOrParish   object        47       0.00
# 17                             MlsStatus   object         1       0.00
# 18                      AttachedGarageYN     bool         2       0.00
# 19                          ParkingTotal  float64        35       0.00
# 20                       PropertySubType   object         1       0.00
# 21                          LotSizeAcres  float64      2904       0.00
# 24                             YearBuilt  float64       138       0.00
# 26                             ListingId   object      9990       0.00
# 27                 BathroomsTotalInteger  float64        12       0.00
# 1                           ListAgentAOR   object        52       0.00
# 55                    AssociationFee_std  float64       597       0.00
#
#     num_missing
# 22         6618
# 23          926
# 6            26
# 25           16
# 11           11
# 0             0
# 42            0
# 33            0
# 34            0
# 35            0
# 36            0
# 37            0
# 38            0
# 39            0
# 40            0
# 41            0
# 43            0
# 31            0
# 44            0
# 45            0
# 46            0
# 47            0
# 48            0
# 49            0
# 50            0
# 51            0
# 52            0
# 53            0
# 54            0
# 32            0
# 28            0
# 30            0
# 14            0
# 2             0
# 3             0
# 4             0
# 5             0
# 7             0
# 8             0
# 9             0
# 10            0
# 12            0
# 13            0
# 15            0
# 29            0
# 16            0
# 17            0
# 18            0
# 19            0
# 20            0
# 21            0
# 24            0
# 26            0
# 27            0
# 1             0
# 55            0

# %%
test_df = test_df.drop(["HighSchoolDistrict_target_mean", "Flooring_target_mean", "LivingArea_std", "LotSizeSquareFeet_std", "AssociationFee_std"], axis=1)

# %%
no_missing_test_df = test_df.dropna(axis=1)

# %%
train_df = no_missing_train_df
test_df = no_missing_test_df

# %%
train_df["log_ClosePrice"] = np.log1p(train_df["ClosePrice"])
train_df.drop(columns=["ClosePrice"], inplace=True)
test_df["log_ClosePrice"] = np.log1p(test_df["ClosePrice"])
test_df.drop(columns=["ClosePrice"], inplace=True)

# %% [markdown]
# # Ridge

# %%
from sklearn.linear_model import Ridge

model = Ridge(alpha=10.0, random_state=42)

ridge_result = fit_predict(
    train_df=train_df,
    test_df=test_df,
    model=model,
    col_drop_list=["ClosePrice"],
    target_col="log_ClosePrice",
    card_threshold=20,
    num_scaler="robust",
    smoothing=10,
    min_samples_leaf=20,
    log_transform=True
)
print(f"R²: {ridge_result['r2']:.4f}")
print(f"MdAPE (%): {ridge_result['mdape']:.2f}")
# Out:
# R²: 0.1202
# MdAPE (%): 33.88

# %% [markdown]
# # ElasticNet

# %%
from sklearn.linear_model import ElasticNet

model = ElasticNet(alpha=0.01, l1_ratio=0.5)

elastic_net_result = fit_predict(
    train_df=train_df,
    test_df=test_df,
    model=model,
    col_drop_list=["ClosePrice"],
    target_col="log_ClosePrice",
    card_threshold=20,
    num_scaler="robust",
    smoothing=10,
    min_samples_leaf=20,
    log_transform=True
)

print(f"R²: {elastic_net_result['r2']:.4f}")
print(f"MdAPE (%): {elastic_net_result['mdape']:.2f}")
# Out:
# R²: 0.7535
# MdAPE (%): 12.17

# %% [markdown]
# # Histogram-based Gradient Boosting Regression Tree

# %%
from sklearn.ensemble import HistGradientBoostingRegressor

model = HistGradientBoostingRegressor(
    max_depth=6,
    learning_rate=0.05,
    max_iter=300,
    random_state=42,
)


hist_tree_result = fit_predict(
    train_df=train_df,
    test_df=test_df,
    model=model,
    col_drop_list=["ClosePrice"],
    target_col="log_ClosePrice",
    card_threshold=20,
    num_scaler="robust",
    smoothing=10,
    min_samples_leaf=20,
    log_transform=True
)

print(f"R²: {hist_tree_result['r2']:.4f}")
print(f"MdAPE (%): {hist_tree_result['mdape']:.2f}")
# Out:
# R²: -0.0359
# MdAPE (%): 39.28

# %% [markdown]
# # Random forest

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(
    n_estimators=300,
    max_depth=12,
    random_state=42,
    n_jobs=-1
)

rf_result = fit_predict(
    train_df=train_df,
    test_df=test_df,
    model=model,
    col_drop_list=["ClosePrice"],
    target_col="log_ClosePrice",
    card_threshold=20,
    num_scaler="robust",
    smoothing=10,
    min_samples_leaf=20,
    log_transform=True
)

print(f"R²: {rf_result['r2']:.4f}")
print(f"MdAPE (%): {rf_result['mdape']:.2f}")
# Out:
# R²: -0.0360
# MdAPE (%): 39.27

# %% [markdown]
# # Multi-layer Perceptron

# %%
from sklearn.neural_network import MLPRegressor

model = MLPRegressor(
    hidden_layer_sizes=(128, 64),
    activation="relu",
    alpha=1e-3,
    learning_rate_init=1e-3,
    max_iter=300,
    early_stopping=True,
    random_state=42
)

mlp_result = fit_predict(
    train_df=train_df,
    test_df=test_df,
    model=model,
    col_drop_list=["ClosePrice"],
    target_col="log_ClosePrice",
    card_threshold=20,
    num_scaler="robust",
    smoothing=10,
    min_samples_leaf=20,
    log_transform=True
)

print(f"R²: {mlp_result['r2']:.4f}")
print(f"MdAPE (%): {mlp_result['mdape']:.2f}")
# Out:
# R²: 0.7983
# MdAPE (%): 12.89

# %% [markdown]
# # Tuning version

# %% [markdown]
# ## Elastic Net

# %%
param_grid = {
    "model__alpha": np.logspace(-4, 2, 25),
    "model__l1_ratio": np.linspace(0.05, 0.95, 19),
}

res = grid_tune_with_make_model_pipeline(
    train_df=train_df,
    target_col="log_ClosePrice",
    model=ElasticNet(max_iter=20000),
    param_grid=param_grid,
    col_drop_list=["ClosePrice"],
    card_threshold=20,
    scoring="r2",
    cv=5
)

best_pipe = res["best_pipeline"]
print(res["best_score"], res["best_params"])
# Out:
# Fitting 5 folds for each of 475 candidates, totalling 2375 fits
# 0.8628536369895269 {'model__alpha': 0.01778279410038923, 'model__l1_ratio': 0.05}

# %%
model = ElasticNet(alpha=res["best_params"]["model__alpha"], l1_ratio=res["best_params"]["model__l1_ratio"])

elastic_net_result = fit_predict(
    train_df=train_df,
    test_df=test_df,
    model=model,
    col_drop_list=["ClosePrice"],
    target_col="log_ClosePrice",
    card_threshold=20,
    num_scaler="robust",
    smoothing=10,
    min_samples_leaf=20,
    log_transform=True
)

print(f"R²: {elastic_net_result['r2']:.4f}")
print(f"MdAPE (%): {elastic_net_result['mdape']:.2f}")
# Out:
# R²: 0.7555
# MdAPE (%): 12.22

# %% [markdown]
# ## MLP

# %%
param_grid_mlp_stable = {
    "model__hidden_layer_sizes": [(128, 64), (256, 128), (256, 128, 64)],
    "model__alpha": [1e-5, 1e-4, 1e-3],
    "model__learning_rate_init": [1e-4, 5e-4, 1e-3],
}

mlp = MLPRegressor(
    activation="relu",
    max_iter=300,
    early_stopping=True,
    random_state=42,
)

res = grid_tune_with_make_model_pipeline(
    train_df=train_df,
    target_col="log_ClosePrice",
    model=mlp,
    param_grid=param_grid_mlp_stable,
    col_drop_list=["ClosePrice"],
    card_threshold=20,
    scoring="r2",
    cv=3,
    n_jobs=-1,
)

print(res["best_score"], res["best_params"])
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# 0.8897492586490818 {'model__alpha': 0.001, 'model__hidden_layer_sizes': (256, 128, 64), 'model__learning_rate_init': 0.001}

# %%
model = MLPRegressor(
    hidden_layer_sizes=res["best_params"]["model__hidden_layer_sizes"],
    activation="relu",
    alpha=res["best_params"]["model__alpha"],
    learning_rate_init=res["best_params"]["model__learning_rate_init"],
    max_iter=300,
    early_stopping=True,
    random_state=42
)

elastic_net_result = fit_predict(
    train_df=train_df,
    test_df=test_df,
    model=model,
    col_drop_list=["ClosePrice"],
    target_col="log_ClosePrice",
    card_threshold=20,
    num_scaler="robust",
    smoothing=10,
    min_samples_leaf=20,
    log_transform=True
)

print(f"R²: {elastic_net_result['r2']:.4f}")
print(f"MdAPE (%): {elastic_net_result['mdape']:.2f}")
# Out:
# R²: 0.8076
# MdAPE (%): 10.28
